# %% [markdown]
# <a href="https://colab.research.google.com/github/aysunmirbyova-rgb/First-ml/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aysunmirbyova-rgb/First-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# I chose the **Content Refresh** lane.

# Many companies have hundreds or thousands of published pages, but limited time to update them. Instead of refreshing pages randomly or simply choosing the oldest ones, I want to build a system that helps prioritize which pages should be updated first.

# This project focuses on supporting SEO and content editors in making better decisions about where to spend their time.
## 2. Research Question

### Research Question

#Which content pages should SEO editors prioritize for updating to maximize search performance?

### Decision

#The decision is which existing pages should be refreshed first when the content team has limited time and resources.

### Who Uses the Output?

#SEO specialists and content editors.

### Action

#Editors will review and update the pages with the highest priority scores before working on lower-priority pages.

### Cost of a Wrong Recommendation

#If a low-value page is prioritized (false positive), editor time is wasted.

#If an important page is not prioritized (false negative), the company may miss opportunities to improve search visibility and organic traffic.

### Why Machine Learning?

#Simple rules such as "refresh the oldest page" or "refresh pages with the most impressions" only consider one factor at a time.

#Search performance depends on many interacting signals, including impressions, clicks, average position, content age, engagement, and freshness. Machine learning can combine these signals to produce a better ranking than a single hand-written rule.

### Task Type

#This is a **ranking** problem because the goal is to rank pages by priority rather than simply classify them as "refresh" or "do not refresh."

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nAverage impressions:")
print(round(df["impressions_90d"].mean(),2))

print("\nMedian days since last update:")
print(df["days_since_last_update"].median())

print("\nPages with more than 500 impressions:")
print((df["impressions_90d"]>500).sum())
# Out:
# Rows: 30000
# Columns: 44
#
# Average impressions:
# 5200.37
#
# Median days since last update:
# 20.0
#
# Pages with more than 500 impressions:
# 16715

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This project does not aim to prove that updating content causes better search performance.

#Instead, it aims to build a decision-support tool that helps prioritize pages using historical search and engagement data.

#Any recommendations produced by the model should support human decision-making rather than replace it.

#The results will show associations in the available data, not causal relationships.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
