# %% [markdown]
# <a href="https://colab.research.google.com/github/aysunmirbyova-rgb/First-ml/blob/main/work/notebooks/Copy_of_w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aysunmirbyova-rgb/First-ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#I chose a classification task. Classification is appropriate because the outcome is a yes/no decision, which can later support prioritizing content updates.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#The target is whether a content item should be refreshed. Since the dataset does not contain a direct human decision label, the label is created using a defined rule (proxy label) based on historical performance. This proxy represents refresh candidates and can be used to train a machine learning model.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#I will use F1-score as the main evaluation metric because both false positives and false negatives matter. A higher F1-score indicates a better balance between precision and recall. I would consider an F1-score above 0.70 to be a good starting point for this task.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# One row represents one content item. Each row contains historical search performance metrics and content-related features for a single piece of content. The machine learning model will make one prediction for each content item.
import os


print(df.shape)
df.head()
# Out:
# (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#A fixed rule cannot capture all the factors that influence content performance. Search performance depends on multiple interacting features such as impressions, CTR, average position, search volume, content length, and user engagement. Machine learning can learn these complex patterns from historical data and make more accurate predictions than a single if-statement or threshold.
df[["impressions_90d", "ctr", "avg_position", "search_volume"]].describe()
# Out:
#        impressions_90d           ctr  avg_position  search_volume
# count     30000.000000  30000.000000   30000.00000   27532.000000
# mean       5200.366300      0.510733      16.34238     158.882391
# std       16838.019547      3.279162      15.21679    1518.270825
# min           1.000000      0.000000       0.00000       0.000000
# 25%          81.000000      0.000000       6.20000       0.000000
# 50%         731.000000      0.070000      10.80000      10.000000
# 75%        3615.250000      0.290000      22.30000      20.000000
# max      517715.000000    100.000000     245.00000   74000.000000

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
